# %% [markdown]
# # Image Annotation
# In the previous modules we have discussed about basic image operations. Before going into advanced topics, let us learn about a simple but important tool in OpenCV - Image Annotation. In this module, we will learn how to annotate an image with
#
# - Line,
# - Circle,
# - Rectangle,
# - Ellipse and
# - Text
#
# These are very useful for showing the output of an algorithm. For example after detecting a face, you need to show the detection result using a rectangle or circle. Similarly, after recognizing an object, you need to show what object it is by writing on top of the object in the image itself and so on..

# %%
# importing libraries
import cv2
import numpy as np
from dataPath import DATA_PATH
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
mpl.rcParams['figure.figsize'] = (6.0, 6.0)
mpl.rcParams['image.cmap'] = 'gray'

# %%
# read and load the image
sample_image_path = DATA_PATH + 'images/face.jpg'

# %%
sample_image = cv2.imread(sample_image_path, cv2.IMREAD_COLOR)

# %%
# display the image
plt.imshow(sample_image[:, :, ::-1])
plt.show()

# %% [markdown]
# ### Draw a Line
# Let's start off by drawing a line on an image. We will use cv2.line function for this.
#
# ### Function Syntax
# line(img, pt1, pt2, color[, thickness[, lineType[, shift]]]) -> img
#
# The arguments that we will focus on are:
#
# - img: Image on which we will draw a line
# - pt1: First point(x,y location) of the line segment
# - pt2: Second point of the line segment
# - color: Color of the line which will be drawn
#
# The above arguments are compulsory. Other arguments that are important for us to know and are optional are:
#
# - thickness: Integer specifying the line thickness. Default value is 1.
# - lineType: Type of the line. Default value is 8 which stands for an 8-connected line. Usually, cv2.LINE_AA (antialiased or smooth line) is used for the lineType.
#
# Let's see an example of this.
#
# Draw a line on his forehead with green color
# From the sample image shown above, we can find that the forehead lies between a y coordinate of 0 to 50 and x coordinate of 100 to 180. Let us take this info and draw a line on his forehead.

# %%
# draw a line
sample_image_line = sample_image.copy()

# The line starts from (200, 80) and ends at (280, 80)
# The color of the line is RED (recall that OpenCV uses BGR format)
# Thickness of line is 5px
# Linetype is cv2.LINE_AA

# We are using semicolon ';' to suppress the output of the statement
cv2.line(sample_image_line, (100, 50), (180, 50), (0, 255, 0), thickness=3, lineType=cv2.LINE_AA);

# %%
# display the sample image
plt.imshow(sample_image_line[:, :, ::-1])
plt.show()

# %% [markdown]
# ### Draw a Circle
# Now let's have a look at the the cv2.circle function which can be used to draw a circle on an image.
#
# ### Function Syntax
# circle(img, center, radius, color[, thickness[, lineType[, shift]]]) -> img
#
# First, the mandatory arguments:
#
# - img: Image where the circle is drawn.
# - center: Center of the circle.
# - radius: Radius of the circle.
# - color: Circle color
#
# Next, let's check out the (optional) arguments which we are going to use quite extensively.
#
# - thickness: Thickness of the circle outline (if positive). If a negative value is supplied for this argument, it will result in a filled circle.
# - lineType: Type of the circle boundary. This is exact same as lineType argument in cv2.line
#
# Draw a circle with center the nose and radius such that the circle approximately covers the face
# We will specify center as (150,100) and radius of 100

# %%
# draw a circle
sample_image_circle = sample_image.copy()
cv2.circle(sample_image_circle, (150, 100), 100, (0, 0, 255), thickness=5, lineType=cv2.LINE_AA);

# %%
# display the sample image
plt.imshow(sample_image_circle[:, :, ::-1])
plt.show()

# %% [markdown]
# ### Draw a filled circle
# For a filled circle, we need to pass the thickness arguments as -1

# %%
# draw a filled circle
sample_image_filled_circle = sample_image.copy()
cv2.circle(sample_image_filled_circle, (150, 100), 100, (0, 0, 255), thickness=-1, lineType=cv2.LINE_AA);

# %%
# display the sample image
plt.imshow(sample_image_filled_circle[:, :, ::-1])
plt.show()

# %% [markdown]
# ### Draw an Ellipse
# Now it's the turn to draw an ellipse using cv2.ellipse function.
#
# ### Function Syntax
# ellipse(img, center, axes, angle, startAngle, endAngle, color[, thickness[, lineType[, shift]]]) -> img
#
# The mandatory arguments are as follows.
#
# - img: Image on which the ellipse is to be drawn.
# - center: Center of the ellipse.
# - axes: radius of the ellipse major and minor axes.
# - angle: Ellipse rotation angle in degrees.
# - startAngle: Starting angle of the elliptic arc in degrees.
# - endAngle: Ending angle of the elliptic arc in degrees.
# - color: Ellipse line color
#
# The optional arguments that we are going to use are the same as before and carry the same meaning.
#
# ### Draw 2 ellipses around his face
# We will draw the first ellipse at an angle of 0 degrees with blue color. The second ellipse will be at 90 degrees with red color
#
# Both ellipses will be complete i.e. the starting angle is 0 and ending angle is 360

# %%
# draw an ellipse; ellipse centers and axis lengths must be integers
sample_image_ellipse = sample_image.copy()
cv2.ellipse(sample_image_ellipse, (150, 100), (100, 50), 0, 0, 360, (255, 0, 0), thickness=3, lineType=cv2.LINE_AA);
cv2.ellipse(sample_image_ellipse, (150, 100), (100, 50), 90, 0, 360, (0, 0, 255), thickness=3, lineType=cv2.LINE_AA);

# %%
# display the new image
plt.imshow(sample_image_ellipse[:, :, ::-1])
plt.show()

# %% [markdown]
# ### Draw more vaiations of the ellipse
# We will draw half ellipses ( i.e. starting angle and ending angles are not 0 to 360 degrees.
#
# Let's draw a ellipse with
#
# starting angle = 180 and ending angle = 360
# starting angle = 0 and ending angle = 180

# %%
# draw an ellipse; ellipse centers and axis lengths must be integers
sample_image_ellipse = sample_image.copy()
cv2.ellipse(sample_image_ellipse, (150, 100), (100, 50), 0, 180, 360, (255, 0, 0), thickness=3, lineType=cv2.LINE_AA);
cv2.ellipse(sample_image_ellipse, (150, 100), (100, 50), 0, 0, 180, (0, 0, 255), thickness=-2, lineType=cv2.LINE_AA);

# %%
# display the image
plt.imshow(sample_image_ellipse[:, :, ::-1])
plt.show()

# %% [markdown]
# ### Draw a Rectangle
# We will use cv2.rectangle function to draw a rectangle on an image. The function syntax is as follows.
#
# ### Function Syntax
# rectangle(img, pt1, pt2, color[, thickness[, lineType[, shift]]]) -> img
#
# The mandatory arguments are as follows.
#
# - img: Image on which the rectangle is to be drawn.
# - pt1: Vertex of the rectangle. Usually we use the top-left vertex here.
# - pt2: Vertex of the rectangle opposite to pt1. Usually we use the bottom-right vertex here.
# - color: Rectangle color
#
# The optional arguments that we are going to use are same as before.
#
# ### Draw a rectangle around his face
# We need two points to draw a rectangle. These are the opposite vertices of the rectangle. From the sample image, we can approximately find the vertices as
#
# - top-left - (180,0)
# - bottom-right - (50,250)

# %%
# draw a rectangle (thickness is a positive integer)
sample_image_rectangle = sample_image.copy()
cv2.rectangle(sample_image_rectangle, (50, 0), (250, 200), (255, 0, 0), thickness=5, lineType=cv2.LINE_8);

# %%
# display the image
plt.imshow(sample_image_rectangle[:, :, ::-1])
plt.show()

# %% [markdown]
# ### Add Text
# Finally, let's see how we can write some text on an image using cv2.putText function.
#
# ### Function Syntax
# putText(img, text, org, fontFace, fontScale, color[, thickness[, lineType[, bottomLeftOrigin]]]) -> img
#
# The mandatory arguments that we need to focus on are:
#
# - img: Image on which the text has to be written.
# - text: Text string to be written.
# - org: Bottom-left corner of the text string in the image.
# - fontFace: Font type
# - fontScale: Font scale factor that is multiplied by the font-specific base size.
# - color: Font color
#
# The optional arguments that we are going to use are same as before.

# %%
# put text into image
sample_image_text = sample_image.copy()
cv2.putText(sample_image_text, 'OpenCV', (50, 300), cv2.FONT_HERSHEY_SIMPLEX, 2, (50, 50, 50), 3, cv2.LINE_AA);

# %%
# display the image
plt.imshow(sample_image_text[:, :, ::-1])
plt.show()
